# %% [markdown]
# ## << 문제 정의 >>
#
# 주어진 titanic dataset을 사용하여 탑승객별로 **생존 여부(Survived)**를 예측하는 문제를 풉니다.
#
# 사용할 데이터는 kaggle에서 제공하는 Titanic Data를 사용합니다. 데이터 설명은 아래 링크를 참고하세요.
#
# 평가하는 성능 지표는 예측한 Survived와 정답 Survived 사이의 **Accuracy**값으로 정의합니다.
#
#
#
# > [Source] https://www.kaggle.com/competitions/titanic/data

# %%
# 0. 라이브러리 및 데이터 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train = pd.read_csv("./train.csv")
test = pd.read_csv("test.csv")
print(train.shape, test.shape)
# Out:
# (891, 12) (418, 11)

# %% [markdown]
# ### Q1. train 데이터의 column별 결측치 비율과 결측치가 하나 이상 포함되어 있는 row의 수를 출력하세요.

# %%
# column별 결측치 비율 출력 코드
for col in train.columns:
  colname = col
  colnum = train[col].isna().sum()/train.shape[0]*100
  print("%-12s  -->  %-4.2f%%" %(colname, colnum))

# 결측치가 하나 이상 포함되어 있는 row의 수 출력 코드
print("결측치를 포함하고 있는 row 수 : ",train.isna().any(axis=1).sum())
# Out:
# PassengerId   -->  0.00%
# Survived      -->  0.00%
# Pclass        -->  0.00%
# Name          -->  0.00%
# Sex           -->  0.00%
# Age           -->  19.87%
# SibSp         -->  0.00%
# Parch         -->  0.00%
# Ticket        -->  0.00%
# Fare          -->  0.00%
# Cabin         -->  77.10%
# Embarked      -->  0.22%
# 결측치를 포함하고 있는 row 수 :  708

# %% [markdown]
# ### Q2. train data에 결측치가 존재하는 column들을 다음과 같은 방법으로 처리하세요.
#
# - Age column은 Age column의 중앙값으로 결측치를 채운다.
#
# - Cabin column은 Cabin column 자체를 제거한다. (column drop)
#
# - Embarked column은 "C"로 결측치를 채운다.

# %%
train.Age = train['Age'].fillna(train['Age'].median())
train = train.drop('Cabin', axis=1)
train.Embarked = train['Embarked'].fillna('C')

# %% [markdown]
# ### Q3. 문자열을 포함하고 있는 column중에 의미가 있다고 판단되는 Sex, Embarked column에 One-Hot Encoding을 적용하세요.

# %%
train = pd.get_dummies(train, columns = ['Sex', 'Embarked'])
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                       Graham, Miss. Margaret Edith  19.0      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  28.0      1      2
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket     Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0           A/5 21171   7.2500       False      True       False       False
# 1            PC 17599  71.2833        True     False        True       False
# 2    STON/O2. 3101282   7.9250        True     False       False       False
# 3              113803  53.1000        True     False       False       False
# 4              373450   8.0500       False      True       False       False
# ..                ...      ...         ...       ...         ...         ...
# 886            211536  13.0000       False      True       False       False
# 887            112053  30.0000        True     False       False       False
# 888        W./C. 6607  23.4500        True     False       False       False
# 889            111369  30.0000       False      True        True       False
# 890            370376   7.7500       False      True       False        True
#
#      Embarked_S
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
# ..          ...
# 886        True
# 887        True
# 888        True
# 889       False
# 890       False
#
# [891 rows x 14 columns]

# %% [markdown]
# ### Q4. 예측 대상인 Survived에 전혀 영향을 주지 않을 column들인 ["PassengerId", "Name", "Ticket"]를 제거하세요.

# %%
drop_cols = ['PassengerId', 'Name', 'Ticket']
train = train.drop(drop_cols, axis=1)
train
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500       False      True
# 1           1       1  38.0      1      0  71.2833        True     False
# 2           1       3  26.0      0      0   7.9250        True     False
# 3           1       1  35.0      1      0  53.1000        True     False
# 4           0       3  35.0      0      0   8.0500       False      True
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 886         0       2  27.0      0      0  13.0000       False      True
# 887         1       1  19.0      0      0  30.0000        True     False
# 888         0       3  28.0      1      2  23.4500        True     False
# 889         1       1  26.0      0      0  30.0000       False      True
# 890         0       3  32.0      0      0   7.7500       False      True
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0         False       False        True
# 1          True       False       False
# 2         False       False        True
# 3         False       False        True
# 4         False       False        True
# ..          ...         ...         ...
# 886       False       False        True
# 887       False       False        True
# 888       False       False        True
# 889        True       False       False
# 890       False        True       False
#
# [891 rows x 11 columns]

# %% [markdown]
# ### Q5. 1주차에 배웠던 코드를 사용해서, train 데이터를 3 : 1의 비율로 나눠서 train, validation 데이터를 만드세요.

# %%
# 4. train-validation split
from sklearn.model_selection import train_test_split

# feature vector
X = train.drop("Survived", axis=1)
# target value
y = train["Survived"]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.25, random_state=42)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (668, 10) (223, 10) (668,) (223,)

# %% [markdown]
# ### Q6. Random Forest를 사용해서 모델을 학습하고, 학습 데이터와 검증 데이터에 대해 Accuracy를 계산하세요.
# (이 때, hyper-parameter는 자유롭게 정해도 됩니다.)

# %%
# 예측에 사용할 모델을 가져와서 학습
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# !pip install --quiet optuna
import optuna

def objective(trial):

  max_depth = (trial.suggest_int("max_depth", 1, 32))
  max_features = trial.suggest_categorical("max_features", ["sqrt", 0.5, "log2", None])
  n_estimators = trial.suggest_int("n_estimators", 2, 400)

  clf = RandomForestClassifier(
      max_depth=max_depth,
      max_features=max_features,
      n_estimators=n_estimators,
      random_state=42
  )

  clf.fit(X_train, y_train)

  return sklearn.model_selection.cross_val_score(
        clf, X_train, y_train, n_jobs=-1, cv=3
    ).mean()

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

trial = study.best_trial
print("Accuracy: {}".format(trial.value))
print("Best hyperparameters: {}".format(trial.params))


best_model = RandomForestClassifier(
    max_depth=study.best_params["max_depth"],
    max_features=study.best_params["max_features"],
    n_estimators=study.best_params["n_estimators"],
    random_state=42
)

best_model.fit(X_train, y_train)
print("Train ACC : %.4f" %accuracy_score(y_train, best_model.predict(X_train)))
print("Validation ACC : %.4f" %accuracy_score(y_val, best_model.predict(X_val)) )
# Out:
# [I 2025-03-21 16:05:48,317] A new study created in memory with name: no-name-e75115d4-fff7-47a9-bbda-b6ea771d2915
# [I 2025-03-21 16:05:52,230] Trial 0 finished with value: 0.780006463862966 and parameters: {'max_depth': 16, 'max_features': 'sqrt', 'n_estimators': 119}. Best is trial 0 with value: 0.780006463862966.
# [I 2025-03-21 16:05:54,177] Trial 1 finished with value: 0.8188637067560834 and parameters: {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 163}. Best is trial 1 with value: 0.8188637067560834.
# [I 2025-03-21 16:05:54,730] Trial 2 finished with value: 0.7814944989832883 and parameters: {'max_depth': 31, 'max_features': None, 'n_estimators': 51}. Best is trial 1 with value: 0.8188637067560834.
# [I 2025-03-21 16:05:55,847] Trial 3 finished with value: 0.8159011028966185 and parameters: {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 138}. Best is trial 1 with value: 0.8188637067560834.
# [I 2025-03-21 16:06:00,462] Trial 4 finished with value: 0.788975073728437 and parameters: {'max_depth': 12, 'max_features': None, 'n_estimators': 307}. Best is trial 1 with value: 0.8188637067560834.
# [I 2025-03-21 16:06:01,926] Trial 5 finished with value: 0.7949608801626739 and parameters: {'max_depth': 15, 'max_features': 0.5, 'n_estimators': 85}. Best is trial 1 with value: 0.8188637067560834.
# [I 2025-03-21 16:06:08,765] Trial 6 finished with value: 0.8039092904563757 and parameters: {'max_depth': 9, 'max_features': 'log2', 'n_estimators': 315}. Best is trial 1 with value: 0.8188637067560834.
# [I 2025-03-21 16:06
. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:18,887] Trial 83 finished with value: 0.8054309915296463 and parameters: {'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 353}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:21,006] Trial 84 finished with value: 0.7874533726551664 and parameters: {'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 311}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:24,574] Trial 85 finished with value: 0.8143659354421686 and parameters: {'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 332}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:27,361] Trial 86 finished with value: 0.8233614780699982 and parameters: {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 389}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:30,194] Trial 87 finished with value: 0.811376398820345 and parameters: {'max_depth': 7, 'max_features': 'log2', 'n_estimators': 384}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:30,440] Trial 88 finished with value: 0.8053973255766977 and parameters: {'max_depth': 9, 'max_features': 'log2', 'n_estimators': 23}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:31,500] Trial 89 finished with value: 0.7874533726551664 and parameters: {'max_depth': 1, 'max_features': 'log2', 'n_estimators': 156}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:32,512] Trial 90 finished with value: 0.7994384519048197 and parameters: {'max_depth': 3, 'max_features': 'log2', 'n_estimators': 143}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:35,406] Trial 91 finished with value: 0.8218599765684967 and parameters: {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 373}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:38,948] Trial 92 finished with value: 0.8068920938876096 and parameters: {'max_depth': 6, 'max_features': 'log2', 'n_estimators': 374}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:41,589] Trial 93 finished with value: 0.7874533726551664 and parameters: {'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 391}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:42,834] Trial 94 finished with value: 0.81586743694367 and parameters: {'max_depth': 5, 'max_features': 'log2', 'n_estimators': 172}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:45,790] Trial 95 finished with value: 0.7919713435408502 and parameters: {'max_depth': 19, 'max_features': 'sqrt', 'n_estimators': 364}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:49,089] Trial 96 finished with value: 0.8128711671312568 and parameters: {'max_depth': 3, 'max_features': 0.5, 'n_estimators': 392}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:51,939] Trial 97 finished with value: 0.8218599765684967 and parameters: {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 322}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:54,850] Trial 98 finished with value: 0.8128779003218464 and parameters: {'max_depth': 5, 'max_features': None, 'n_estimators': 351}. Best is trial 51 with value: 0.8233614780699982.
# [I 2025-03-21 16:09:55,553] Trial 99 finished with value: 0.8158539705624906 and parameters: {'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 95}. Best is trial 51 with value: 0.8233614780699982.
# Accuracy: 0.8233614780699982
# Best hyperparameters: {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 376}
# Train ACC : 0.8518
# Validation ACC : 0.8117

# %% [markdown]
# ### Q7. test 데이터를 앞에서 수행했던 모든 전처리를 그대로 이용해서 Q6에서 학습한 모델로 결과를 출력할 수 있게 만드세요.
#
# 학습한 모델로 출력 결과가 나온다는 것은 아래 작성된 `clf.predict(X_test)`를 실행했을 때 어떠한 warning이나 error없이 실행되는 것을 말합니다.
#
# - 주의 : test data를 앞에서 사용한 방식으로 전처리를 하려고 하면, Fare column의 결측치를 처리할 방법이 없을겁니다. Fare column의 결측치는 train data의 Fare column의 평균값을 계산해서 채워주세요.

# %%
# X_test를 만들어서 아래 코드를 실행하세요.
test.Fare = test['Fare'].fillna(test['Fare'].mean())
test.Age = test['Age'].fillna(test['Age'].median())
test = test.drop('Cabin', axis=1)
test.Embarked = test['Embarked'].fillna('C')
drop_cols = ['PassengerId', 'Name', 'Ticket']
test = pd.get_dummies(test, columns = ['Sex', 'Embarked'])
test = test.drop(drop_cols, axis=1)
X_test = test
output = best_model.predict(X_test)
assert len(output) == 418  # sanity check

# %% [markdown]
# ### Q8. 계산한 output을 사용하여 제출 파일인 submission.csv를 만드세요. submission.csv의 Survived column에 output 결과를 덮어쓰면 됩니다.
#
# 제출 파일의 이름은 submission.csv이며 아래 코드의 submission DataFrame을 완성하면 자동으로 생성됩니다.

# %%
# submission DataFrame을 만들어서 아래 코드를 실행하세요.
submission = pd.read_csv("gender_submission.csv")
submission.Survived = output
submission.to_csv('submission.csv', index=False)
